# %% [markdown]
# <a href="https://colab.research.google.com/github/aviadr1/learn-advanced-python/blob/master/content/14_pandas/pandas_a_quick_tour.ipynb" target="_blank">
# <img src="https://colab.research.google.com/assets/colab-badge.svg"
#      title="Open this file in Google Colab" alt="Colab"/>
# </a>

# %%
x=0

# %%
import pandas as pd

# %%
df = pd.read_csv('diamonds.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# df.head() 
df.head(10)
# Out:
#     #  carat        cut color clarity  depth  table  price     x     y     z
# 0   1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   9   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9  10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.tail()
# Out:
#            #  carat        cut color clarity  ...  table  price     x     y     z
# 53935  53936   0.72      Ideal     D     SI1  ...   57.0   2757  5.75  5.76  3.50
# 53936  53937   0.72       Good     D     SI1  ...   55.0   2757  5.69  5.75  3.61
# 53937  53938   0.70  Very Good     D     SI1  ...   60.0   2757  5.66  5.68  3.56
# 53938  53939   0.86    Premium     H     SI2  ...   58.0   2757  6.15  6.12  3.74
# 53939  53940   0.75      Ideal     D     SI2  ...   55.0   2757  5.83  5.87  3.64
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
# #          53940 non-null int64
# carat      53940 non-null float64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#                   #         carat  ...             y             z
# count  53940.000000  53940.000000  ...  53940.000000  53940.000000
# mean   26970.500000      0.797940  ...      5.734526      3.538734
# std    15571.281097      0.474011  ...      1.142135      0.705699
# min        1.000000      0.200000  ...      0.000000      0.000000
# 25%    13485.750000      0.400000  ...      4.720000      2.910000
# 50%    26970.500000      0.700000  ...      5.710000      3.530000
# 75%    40455.250000      1.040000  ...      6.540000      4.040000
# max    53940.000000      5.010000  ...     58.900000     31.800000
#
# [8 rows x 8 columns]

# %%
df['carat'].head()
# Out:
# 0    0.23
# 1    0.21
# 2    0.23
# 3    0.29
# 4    0.31
# Name: carat, dtype: float64

# %%
df[['carat', 'price']].head()
# df[  ['carat', 'price']  ].head()
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335

# %%
df.iloc[0]
# Out:
# #              1
# carat       0.23
# cut        Ideal
# color          E
# clarity      SI2
# depth       61.5
# table         55
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object

# %%
# df.iloc[0]['carat']
df.iloc[0][['carat', 'price']]
# Out:
# carat    0.23
# price     326
# Name: 0, dtype: object

# %%
df.iloc[:10]
# Out:
#     #  carat        cut color clarity  depth  table  price     x     y     z
# 0   1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   2   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   4   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   5   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   9   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9  10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
df.iloc[ [0, 2, 1, 0] ]
# Out:
#    #  carat      cut color clarity  depth  table  price     x     y     z
# 0  1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2  3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 1  2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0  1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
row0 = df.iloc[0]
row0
# Out:
# #              1
# carat       0.23
# cut        Ideal
# color          E
# clarity      SI2
# depth       61.5
# table         55
# price        326
# x           3.95
# y           3.98
# z           2.43
# Name: 0, dtype: object

# %%
row0['price']
# Out:
# 326

# %%
row0.iloc[1]
# Out:
# 0.23

# %%
row0.loc['price']
# Out:
# 326

# %%
carats = df.set_index('carat')
carats.head()
# Out:
#        #      cut color clarity  depth  table  price     x     y     z
# carat
# 0.23   1    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21   2  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23   3     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29   4  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31   5     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
carats.loc[0.21]
# Out:
#            #        cut color clarity  depth  table  price     x     y     z
# carat
# 0.21       2    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.21   38274  Very Good     E     VS2   63.2   54.0    386  3.82  3.78  2.40
# 0.21   38275    Premium     E     VS2   60.5   59.0    386  3.87  3.83  2.33
# 0.21   38276    Premium     E     VS2   59.6   56.0    386  3.93  3.89  2.33
# 0.21   38277    Premium     D     VS2   61.6   59.0    386  3.82  3.78  2.34
# 0.21   38278    Premium     D     VS2   60.6   60.0    386  3.85  3.81  2.32
# 0.21   38279    Premium     D     VS2   59.1   62.0    386  3.89  3.86  2.29
# 0.21   38280    Premium     D     VS2   58.3   59.0    386  3.96  3.93  2.30
# 0.21   43990    Premium     E     SI2   61.9   56.0    394  3.84  3.82  2.37

# %%
carats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 53940 entries, 0.23 to 0.75
# Data columns (total 10 columns):
# #          53940 non-null int64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 5.8+ MB

# %%
carats.reset_index()
# Out:
#        carat      #        cut color clarity  ...  table  price     x     y     z
# 0       0.23      1      Ideal     E     SI2  ...   55.0    326  3.95  3.98  2.43
# 1       0.21      2    Premium     E     SI1  ...   61.0    326  3.89  3.84  2.31
# 2       0.23      3       Good     E     VS1  ...   65.0    327  4.05  4.07  2.31
# 3       0.29      4    Premium     I     VS2  ...   58.0    334  4.20  4.23  2.63
# 4       0.31      5       Good     J     SI2  ...   58.0    335  4.34  4.35  2.75
# 5       0.24      6  Very Good     J    VVS2  ...   57.0    336  3.94  3.96  2.48
# 6       0.24      7  Very Good     I    VVS1  ...   57.0    336  3.95  3.98  2.47
# 7       0.26      8  Very Good     H     SI1  ...   55.0    337  4.07  4.11  2.53
# 8       0.22      9       Fair     E     VS2  ...   61.0    337  3.87  3.78  2.49
# 9       0.23     10  Very Good     H     VS1  ...   61.0    338  4.00  4.05  2.39
# 10      0.30     11       Good     J     SI1  ...   55.0    339  4.25  4.28  2.73
# 11      0.23     12      Ideal     J     VS1  ...   56.0    340  3.93  3.90  2.46
# 12      0.22     13    Premium     F     SI1  ...   61.0    342  3.88  3.84  2.33
# 13      0.31     14      Ideal     J     SI2  ...   54.0    344  4.35  4.37  2.71
# 14      0.20     15    Premium     E     SI2  ...   62.0    345  3.79  3.75  2.27
# 15      0.32     16    Premium     E      I1  ...   58.0    345  4.38  4.42  2.68
# 16      0.30     17      Ideal     I     SI2  ...   54.0    348  4.31  4.34  2.68
# 17      0.30     18       Good     J     SI1  ...   54.0    351  4.23  4.29  2.70
# 18      0.30     19       Good     J     SI1  ...   56.0    351  4.23  4.26  2.71
# 19      0.30     20  Very Good     J     SI1  ...   59.0    351  4.21  4.27  2.66
# 20      0.30     21       Good     I     SI2  ...   56.0    351  4.26  4.30  2.71
# 21      0.23     22  Very Good     E     VS2  ...   55.0    352  3.85  3.92  2.48
# 22      0.23     23  Very Good     H     VS1  ...   57.0    353  3.94  3.96  2.41
# 23      0.31     24  Very Good     J     SI1  ...   62.0    353  4.39  4.43  2.62
# 24      0.31     25  Very Good     J     SI1  ...   62.0    353  4.44  4.47  2.59
# 25      0.23     26  Very Good     G    VVS2  ...   58.0    354  3.97  4.01  2.41
# 26      0.24     27    Premium     I     VS1  ...   57.0    355  3.97  3.94  2.47
# 27      0.30     28  Very Good     J     VS2  ...   57.0    357  4.28  4.30  2.67
# 28      0.23     29  Very Good     D     VS2  ...   61.0    357  3.96  3.97  2.40
# 29      0.23     30  Very Good     F     VS1  ...   57.0    357  3.96  3.99  2.42
# ...      ...    ...        ...   ...     ...  ...    ...    ...   ...   ...   ...
# 53910   0.70  53911    Premium     E     SI1  ...   58.0   2753  5.74  5.77  3.48
# 53911   0.57  53912    Premium     E      IF  ...   60.0   2753  5.43  5.38  3.23
# 53912   0.61  53913    Premium     F    VVS1  ...   59.0   2753  5.48  5.40  3.36
# 53913   0.80  53914       Good     G     VS2  ...   58.0   2753  5.84  5.81  3.74
# 53914   0.84  53915       Good     I     VS1  ...   59.0   2753  5.94  5.90  3.77
# 53915   0.77  53916      Ideal     E     SI2  ...   56.0   2753  5.84  5.86  3.63
# 53916   0.74  53917       Good     D     SI1  ...   59.0   2753  5.71  5.74  3.61
# 53917   0.90  53918  Very Good     J     SI1  ...   60.0   2753  6.12  6.09  3.86
# 53918   0.76  53919    Premium     I     VS1  ...   62.0   2753  5.93  5.85  3.49
# 53919   0.76  53920      Ideal     I    VVS1  ...   55.0   2753  5.89  5.87  3.66
# 53920   0.70  53921  Very Good     E     VS2  ...   60.0   2755  5.57  5.61  3.49
# 53921   0.70  53922  Very Good     E     VS2  ...   60.0   2755  5.59  5.65  3.53
# 53922   0.70  53923  Very Good     D     VS1  ...   59.0   2755  5.67  5.58  3.55
# 53923   0.73  53924      Ideal     I     VS2  ...   56.0   2756  5.80  5.84  3.57
# 53924   0.73  53925      Ideal     I     VS2  ...   55.0   2756  5.82  5.84  3.59
# 53925   0.79  53926      Ideal     I     SI1  ...   56.0   2756  5.95  5.97  3.67
# 53926   0.71  53927      Ideal     E     SI1  ...   56.0   2756  5.71  5.73  3.54
# 53927   0.79  53928       Good     F     SI1  ...   59.0   2756  6.06  6.13  3.54
# 53928   0.79  53929    Premium     E     SI2  ...   58.0   2756  6.03  5.96  3.68
# 53929   0.71  53930      Ideal     G     VS1  ...   56.0   2756  5.76  5.73  3.53
# 53930   0.71  53931    Premium     E     SI1  ...   55.0   2756  5.79  5.74  3.49
# 53931   0.71  53932    Premium     F     SI1  ...   62.0   2756  5.74  5.73  3.43
# 53932   0.70  53933  Very Good     E     VS2  ...   59.0   2757  5.71  5.76  3.47
# 53933   0.70  53934  Very Good     E     VS2  ...   59.0   2757  5.69  5.72  3.49
# 53934   0.72  53935    Premium     D     SI1  ...   59.0   2757  5.69  5.73  3.58
# 53935   0.72  53936      Ideal     D     SI1  ...   57.0   2757  5.75  5.76  3.50
# 53936   0.72  53937       Good     D     SI1  ...   55.0   2757  5.69  5.75  3.61
# 53937   0.70  53938  Very Good     D     SI1  ...   60.0   2757  5.66  5.68  3.56
# 53938   0.86  53939    Premium     H     SI2  ...   58.0   2757  6.15  6.12  3.74
# 53939   0.75  53940      Ideal     D     SI2  ...   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
df.head()
# Out:
#    #  carat      cut color clarity  depth  table  price     x     y     z
# 0  1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1  2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2  3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3  4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4  5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.head() *2
# Out:
#     #  carat             cut color clarity  ...  table  price     x     y     z
# 0   2   0.46      IdealIdeal    EE  SI2SI2  ...  110.0    652  7.90  7.96  4.86
# 1   4   0.42  PremiumPremium    EE  SI1SI1  ...  122.0    652  7.78  7.68  4.62
# 2   6   0.46        GoodGood    EE  VS1VS1  ...  130.0    654  8.10  8.14  4.62
# 3   8   0.58  PremiumPremium    II  VS2VS2  ...  116.0    668  8.40  8.46  5.26
# 4  10   0.62        GoodGood    JJ  SI2SI2  ...  116.0    670  8.68  8.70  5.50
#
# [5 rows x 11 columns]

# %%
(df['carat'] + 1).head()
# Out:
# 0    1.23
# 1    1.21
# 2    1.23
# 3    1.29
# 4    1.31
# Name: carat, dtype: float64

# %%
df['expensive'] = df['price'] > 1000
df.head()
# Out:
#    #  carat      cut color clarity  ...  price     x     y     z  expensive
# 0  1   0.23    Ideal     E     SI2  ...    326  3.95  3.98  2.43      False
# 1  2   0.21  Premium     E     SI1  ...    326  3.89  3.84  2.31      False
# 2  3   0.23     Good     E     VS1  ...    327  4.05  4.07  2.31      False
# 3  4   0.29  Premium     I     VS2  ...    334  4.20  4.23  2.63      False
# 4  5   0.31     Good     J     SI2  ...    335  4.34  4.35  2.75      False
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#            #  carat        cut color  ...     x     y     z  expensive
# 53935  53936   0.72      Ideal     D  ...  5.75  5.76  3.50       True
# 53936  53937   0.72       Good     D  ...  5.69  5.75  3.61       True
# 53937  53938   0.70  Very Good     D  ...  5.66  5.68  3.56       True
# 53938  53939   0.86    Premium     H  ...  6.15  6.12  3.74       True
# 53939  53940   0.75      Ideal     D  ...  5.83  5.87  3.64       True
#
# [5 rows x 12 columns]

# %%
def is_large(row):
    vol = row['x'] * row['y'] * row['z']
    if vol > 20:
        return "big"

    else:
        return "small"

# %%
df['volume_label'] = df.apply(is_large, axis=1)
df.head()
# Out:
#    #  carat      cut color clarity  ...     x     y     z  expensive  volume_label
# 0  1   0.23    Ideal     E     SI2  ...  3.95  3.98  2.43      False           big
# 1  2   0.21  Premium     E     SI1  ...  3.89  3.84  2.31      False           big
# 2  3   0.23     Good     E     VS1  ...  4.05  4.07  2.31      False           big
# 3  4   0.29  Premium     I     VS2  ...  4.20  4.23  2.63      False           big
# 4  5   0.31     Good     J     SI2  ...  4.34  4.35  2.75      False           big
#
# [5 rows x 13 columns]

# %%
df['expensive'].replace({True: 'yes!', False: 'no...'})
# Out:
# 0        no...
# 1        no...
# 2        no...
# 3        no...
# 4        no...
# 5        no...
# 6        no...
# 7        no...
# 8        no...
# 9        no...
# 10       no...
# 11       no...
# 12       no...
# 13       no...
# 14       no...
# 15       no...
# 16       no...
# 17       no...
# 18       no...
# 19       no...
# 20       no...
# 21       no...
# 22       no...
# 23       no...
# 24       no...
# 25       no...
# 26       no...
# 27       no...
# 28       no...
# 29       no...
#          ...
# 53910     yes!
# 53911     yes!
# 53912     yes!
# 53913     yes!
# 53914     yes!
# 53915     yes!
# 53916     yes!
# 53917     yes!
# 53918     yes!
# 53919     yes!
# 53920     yes!
# 53921     yes!
# 53922     yes!
# 53923     yes!
# 53924     yes!
# 53925     yes!
# 53926     yes!
# 53927     yes!
# 53928     yes!
# 53929     yes!
# 53930     yes!
# 53931     yes!
# 53932     yes!
# 53933     yes!
# 53934     yes!
# 53935     yes!
# 53936     yes!
# 53937     yes!
# 53938     yes!
# 53939     yes!
# Name: expensive, Length: 53940, dtype: object

# %%
def depth_as_inch(row):
    inch = row['depth'] / 3
    row.drop('depth')
    return row

df.apply(depth_as_inch, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-b433f0a70d86> in <module>()
#       4     return row
#       5
# ----> 6 df.apply(depth_as_inch, axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-48-b433f0a70d86> in depth_as_inch(row)
#       1 def depth_as_inch(row):
#       2     inch = row['depth'] / 3
# ----> 3     pd.concat([row.drop('depth'), inch])
#       4     return row
#       5
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     287                        ' only pd.Series, pd.DataFrame, and pd.Panel'
#     288                        ' (deprecated) objs are valid'.format(type(obj)))
# --> 289                 raise TypeError(msg)
#     290
#     291             # consolidate
#
# TypeError: ('cannot concatenate object of type "<class \'float\'>"; only pd.Series, pd.DataFrame, and pd.Panel (deprecated) objs are valid', 'occurred at index 0')

# %%
df['carat'] + 1
# Out:
# 0        1.23
# 1        1.21
# 2        1.23
# 3        1.29
# 4        1.31
# 5        1.24
# 6        1.24
# 7        1.26
# 8        1.22
# 9        1.23
# 10       1.30
# 11       1.23
# 12       1.22
# 13       1.31
# 14       1.20
# 15       1.32
# 16       1.30
# 17       1.30
# 18       1.30
# 19       1.30
# 20       1.30
# 21       1.23
# 22       1.23
# 23       1.31
# 24       1.31
# 25       1.23
# 26       1.24
# 27       1.30
# 28       1.23
# 29       1.23
#          ...
# 53910    1.70
# 53911    1.57
# 53912    1.61
# 53913    1.80
# 53914    1.84
# 53915    1.77
# 53916    1.74
# 53917    1.90
# 53918    1.76
# 53919    1.76
# 53920    1.70
# 53921    1.70
# 53922    1.70
# 53923    1.73
# 53924    1.73
# 53925    1.79
# 53926    1.71
# 53927    1.79
# 53928    1.79
# 53929    1.71
# 53930    1.71
# 53931    1.71
# 53932    1.70
# 53933    1.70
# 53934    1.72
# 53935    1.72
# 53936    1.72
# 53937    1.70
# 53938    1.86
# 53939    1.75
# Name: carat, Length: 53940, dtype: float64

# %%
df
# Out:
#            #  carat        cut color  ...     y     z  expensive  volume_label
# 0          1   0.23      Ideal     E  ...  3.98  2.43      False           big
# 1          2   0.21    Premium     E  ...  3.84  2.31      False           big
# 2          3   0.23       Good     E  ...  4.07  2.31      False           big
# 3          4   0.29    Premium     I  ...  4.23  2.63      False           big
# 4          5   0.31       Good     J  ...  4.35  2.75      False           big
# 5          6   0.24  Very Good     J  ...  3.96  2.48      False           big
# 6          7   0.24  Very Good     I  ...  3.98  2.47      False           big
# 7          8   0.26  Very Good     H  ...  4.11  2.53      False           big
# 8          9   0.22       Fair     E  ...  3.78  2.49      False           big
# 9         10   0.23  Very Good     H  ...  4.05  2.39      False           big
# 10        11   0.30       Good     J  ...  4.28  2.73      False           big
# 11        12   0.23      Ideal     J  ...  3.90  2.46      False           big
# 12        13   0.22    Premium     F  ...  3.84  2.33      False           big
# 13        14   0.31      Ideal     J  ...  4.37  2.71      False           big
# 14        15   0.20    Premium     E  ...  3.75  2.27      False           big
# 15        16   0.32    Premium     E  ...  4.42  2.68      False           big
# 16        17   0.30      Ideal     I  ...  4.34  2.68      False           big
# 17        18   0.30       Good     J  ...  4.29  2.70      False           big
# 18        19   0.30       Good     J  ...  4.26  2.71      False           big
# 19        20   0.30  Very Good     J  ...  4.27  2.66      False           big
# 20        21   0.30       Good     I  ...  4.30  2.71      False           big
# 21        22   0.23  Very Good     E  ...  3.92  2.48      False           big
# 22        23   0.23  Very Good     H  ...  3.96  2.41      False           big
# 23        24   0.31  Very Good     J  ...  4.43  2.62      False           big
# 24        25   0.31  Very Good     J  ...  4.47  2.59      False           big
# 25        26   0.23  Very Good     G  ...  4.01  2.41      False           big
# 26        27   0.24    Premium     I  ...  3.94  2.47      False           big
# 27        28   0.30  Very Good     J  ...  4.30  2.67      False           big
# 28        29   0.23  Very Good     D  ...  3.97  2.40      False           big
# 29        30   0.23  Very Good     F  ...  3.99  2.42      False           big
# ...      ...    ...        ...   ...  ...   ...   ...        ...           ...
# 53910  53911   0.70    Premium     E  ...  5.77  3.48       True           big
# 53911  53912   0.57    Premium     E  ...  5.38  3.23       True           big
# 53912  53913   0.61    Premium     F  ...  5.40  3.36       True           big
# 53913  53914   0.80       Good     G  ...  5.81  3.74       True           big
# 53914  53915   0.84       Good     I  ...  5.90  3.77       True           big
# 53915  53916   0.77      Ideal     E  ...  5.86  3.63       True           big
# 53916  53917   0.74       Good     D  ...  5.74  3.61       True           big
# 53917  53918   0.90  Very Good     J  ...  6.09  3.86       True           big
# 53918  53919   0.76    Premium     I  ...  5.85  3.49       True           big
# 53919  53920   0.76      Ideal     I  ...  5.87  3.66       True           big
# 53920  53921   0.70  Very Good     E  ...  5.61  3.49       True           big
# 53921  53922   0.70  Very Good     E  ...  5.65  3.53       True           big
# 53922  53923   0.70  Very Good     D  ...  5.58  3.55       True           big
# 53923  53924   0.73      Ideal     I  ...  5.84  3.57       True           big
# 53924  53925   0.73      Ideal     I  ...  5.84  3.59       True           big
# 53925  53926   0.79      Ideal     I  ...  5.97  3.67       True           big
# 53926  53927   0.71      Ideal     E  ...  5.73  3.54       True           big
# 53927  53928   0.79       Good     F  ...  6.13  3.54       True           big
# 53928  53929   0.79    Premium     E  ...  5.96  3.68       True           big
# 53929  53930   0.71      Ideal     G  ...  5.73  3.53       True           big
# 53930  53931   0.71    Premium     E  ...  5.74  3.49       True           big
# 53931  53932   0.71    Premium     F  ...  5.73  3.43       True           big
# 53932  53933   0.70  Very Good     E  ...  5.76  3.47       True           big
# 53933  53934   0.70  Very Good     E  ...  5.72  3.49       True           big
# 53934  53935   0.72    Premium     D  ...  5.73  3.58       True           big
# 53935  53936   0.72      Ideal     D  ...  5.76  3.50       True           big
# 53936  53937   0.72       Good     D  ...  5.75  3.61       True           big
# 53937  53938   0.70  Very Good     D  ...  5.68  3.56       True           big
# 53938  53939   0.86    Premium     H  ...  6.12  3.74       True           big
# 53939  53940   0.75      Ideal     D  ...  5.87  3.64       True           big
#
# [53940 rows x 13 columns]

# %%
df.groupby('cut').mean()
# Out:
#                       #     carat      depth  ...         y         z  expensive
# cut                                           ...
# Fair       24147.357764  1.046137  64.041677  ...  6.182652  3.982770   0.931056
# Good       24774.931309  0.849185  62.365879  ...  5.850744  3.639507   0.773339
# Ideal      29047.630736  0.702837  61.709401  ...  5.520080  3.401448   0.682103
# Premium    25600.209049  0.891955  61.264673  ...  5.944879  3.647124   0.767675
# Very Good  26097.313193  0.806381  61.818275  ...  5.770026  3.559801   0.731336
#
# [5 rows x 9 columns]

# %%
df.groupby('cut')[['price', 'carat']].mean()
# Out:
#                  price     carat
# cut
# Fair       4358.757764  1.046137
# Good       3928.864452  0.849185
# Ideal      3457.541970  0.702837
# Premium    4584.257704  0.891955
# Very Good  3981.759891  0.806381

# %%
clarity_cut = df.groupby(['cut', 'clarity'])[['price', 'carat']].mean()
clarity_cut.head()
# Out:
#                     price     carat
# cut  clarity
# Fair I1       3703.533333  1.361000
#      IF       1912.333333  0.474444
#      SI1      4208.279412  0.964632
#      SI2      5173.916309  1.203841
#      VS1      4165.141176  0.879824

# %%
clarity_cut['price'].sort_values(ascending = False)
# Out:
# cut        clarity
# Premium    SI2        5545.936928
# Fair       SI2        5173.916309
# Very Good  SI2        4988.688095
# Ideal      SI2        4755.952656
# Good       SI2        4580.260870
# Premium    VS2        4550.331248
#            VS1        4485.462041
#            SI1        4455.269371
# Very Good  IF         4396.216418
# Ideal      I1         4335.726027
# Good       VS2        4262.236196
# Very Good  VS2        4215.759552
# Fair       SI1        4208.279412
#            VS2        4174.724138
#            VS1        4165.141176
# Good       IF         4098.323944
# Very Good  I1         4078.226190
# Premium    I1         3947.331707
# Very Good  SI1        3932.391049
# Fair       VVS1       3871.352941
# Premium    IF         3856.143478
# Very Good  VS1        3805.353239
# Good       VS1        3801.445988
# Premium    VVS2       3795.122989
# Ideal      SI1        3752.118169
# Fair       I1         3703.533333
# Good       SI1        3689.533333
#            I1         3596.635417
# Ideal      VS1        3489.744497
# Fair       VVS2       3349.768116
# Ideal      VS2        3284.550385
#            VVS2       3250.290100
# Good       VVS2       3079.108392
# Very Good  VVS2       3037.765182
# Premium    VVS1       2831.206169
# Ideal      VVS1       2468.129458
# Very Good  VVS1       2459.441065
# Ideal      IF         2272.913366
# Good       VVS1       2254.774194
# Fair       IF         1912.333333
# Name: price, dtype: float64

# %%
df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df.head()
# Out:
#    #  carat      cut color clarity  ...     x     y     z  expensive  volume_label
# 0  1   0.23    Ideal     E     SI2  ...  3.95  3.98  2.43      False           big
# 1  2   0.21  Premium     E     SI1  ...  3.89  3.84  2.31      False           big
# 2  3   0.23     Good     E     VS1  ...  4.05  4.07  2.31      False           big
# 3  4   0.29  Premium     I     VS2  ...  4.20  4.23  2.63      False           big
# 4  5   0.31     Good     J     SI2  ...  4.34  4.35  2.75      False           big
#
# [5 rows x 13 columns]

# %%
df.plot.scatter(x='x', y='y')

# %%
df.plot.scatter(x='carat', y='price')

# %%
df.groupby('cut')['price'].mean().plot.bar()

# %%
df['cut'] = df['cut'].astype(pd.CategoricalDtype(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], ordered=True))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 13 columns):
# #               53940 non-null int64
# carat           53940 non-null float64
# cut             53940 non-null category
# color           53940 non-null object
# clarity         53940 non-null object
# depth           53940 non-null float64
# table           53940 non-null float64
# price           53940 non-null int64
# x               53940 non-null float64
# y               53940 non-null float64
# z               53940 non-null float64
# expensive       53940 non-null bool
# volume_label    53940 non-null object
# dtypes: bool(1), category(1), float64(6), int64(2), object(3)
# memory usage: 4.6+ MB

# %%
df.groupby('cut')['price'].mean().plot.bar()

# %%
df.groupby('cut')['price'].mean().sort_values().plot.bar()

# %%
mask = df['cut'] == "Ideal"
df[mask].head()
# Out:
#      #  carat    cut color clarity  ...     x     y     z  expensive  volume_label
# 0    1   0.23  Ideal     E     SI2  ...  3.95  3.98  2.43      False           big
# 11  12   0.23  Ideal     J     VS1  ...  3.93  3.90  2.46      False           big
# 13  14   0.31  Ideal     J     SI2  ...  4.35  4.37  2.71      False           big
# 16  17   0.30  Ideal     I     SI2  ...  4.31  4.34  2.68      False           big
# 39  40   0.33  Ideal     I     SI2  ...  4.49  4.51  2.78      False           big
#
# [5 rows x 13 columns]

# %%
mask = (df['cut'] == "Ideal") & (df['color'] == 'J')
df[mask].head()
# Out:
#        #  carat    cut color clarity  ...     x     y     z  expensive  volume_label
# 11    12   0.23  Ideal     J     VS1  ...  3.93  3.90  2.46      False           big
# 13    14   0.31  Ideal     J     SI2  ...  4.35  4.37  2.71      False           big
# 41    42   0.33  Ideal     J     SI1  ...  4.49  4.55  2.76      False           big
# 460  461   0.90  Ideal     J     VS2  ...  6.20  6.16  3.88       True           big
# 681  682   0.75  Ideal     J     SI1  ...  5.83  5.87  3.60       True           big
#
# [5 rows x 13 columns]

# %%
df[   (df['cut'] == "Ideal") & (df['color'] == 'J')  ].head()
# Out:
#        #  carat    cut color clarity  ...     x     y     z  expensive  volume_label
# 11    12   0.23  Ideal     J     VS1  ...  3.93  3.90  2.46      False           big
# 13    14   0.31  Ideal     J     SI2  ...  4.35  4.37  2.71      False           big
# 41    42   0.33  Ideal     J     SI1  ...  4.49  4.55  2.76      False           big
# 460  461   0.90  Ideal     J     VS2  ...  6.20  6.16  3.88       True           big
# 681  682   0.75  Ideal     J     SI1  ...  5.83  5.87  3.60       True           big
#
# [5 rows x 13 columns]

# %%
df[df['price'] > 1000].head()
# Out:
#      #  carat        cut color  ...     y     z  expensive  volume_label
# 90  91   0.70      Ideal     E  ...  5.72  3.57       True           big
# 91  92   0.86       Fair     E  ...  6.33  3.52       True           big
# 92  93   0.70      Ideal     G  ...  5.67  3.50       True           big
# 93  94   0.71  Very Good     E  ...  5.73  3.56       True           big
# 94  95   0.78  Very Good     G  ...  5.85  3.72       True           big
#
# [5 rows x 13 columns]

# %%
df.loc[[90, 91]]
# Out:
#      #  carat    cut color clarity  ...     x     y     z  expensive  volume_label
# 90  91   0.70  Ideal     E     SI1  ...  5.70  5.72  3.57       True           big
# 91  92   0.86   Fair     E     SI2  ...  6.45  6.33  3.52       True           big
#
# [2 rows x 13 columns]

# %%
df = pd.read_csv('crimes.csv', parse_dates=['Dates'], index_col='Dates')
df.head()
# Out:
#                            Category  ...          Y
# Dates                                ...
# 2015-05-13 23:53:00        WARRANTS  ...  37.774599
# 2015-05-13 23:53:00  OTHER OFFENSES  ...  37.774599
# 2015-05-13 23:33:00  OTHER OFFENSES  ...  37.800414
# 2015-05-13 23:30:00   LARCENY/THEFT  ...  37.800873
# 2015-05-13 23:30:00   LARCENY/THEFT  ...  37.771541
#
# [5 rows x 8 columns]

# %%
df = pd.read_csv('crimes.csv')
df['Dates'] = pd.to_datetime(df.Dates)
df.set_index('Dates', inplace=True)
df.head(10)

# %%
mask = (df['Category'] != 'OTHER OFFENSES') & (df['Category'] != 'NON-CRIMINAL')

# %%
df = df.loc[mask, :]
print(df.shape)
df.head(20)
# Out:
# (176285, 8)
#                           Category  ...          Y
# Dates                               ...
# 2015-05-13 23:53:00       WARRANTS  ...  37.774599
# 2015-05-13 23:30:00  LARCENY/THEFT  ...  37.800873
# 2015-05-13 23:30:00  LARCENY/THEFT  ...  37.771541
# 2015-05-13 23:30:00  LARCENY/THEFT  ...  37.713431
# 2015-05-13 23:30:00  VEHICLE THEFT  ...  37.725138
# 2015-05-13 23:30:00  VEHICLE THEFT  ...  37.727564
# 2015-05-13 23:00:00  LARCENY/THEFT  ...  37.776601
# 2015-05-13 23:00:00  LARCENY/THEFT  ...  37.807802
# 2015-05-13 22:58:00  LARCENY/THEFT  ...  37.807802
# 2015-05-13 22:30:00      VANDALISM  ...  37.783004
# 2015-05-13 22:06:00  LARCENY/THEFT  ...  37.784353
# 2015-05-13 22:00:00        ROBBERY  ...  37.783932
# 2015-05-13 21:55:00        ASSAULT  ...  37.742822
# 2015-05-13 21:30:00  LARCENY/THEFT  ...  37.742669
# 2015-05-13 21:17:00        ROBBERY  ...  37.747332
# 2015-05-13 21:11:00       WARRANTS  ...  37.782556
# 2015-05-13 21:10:00  LARCENY/THEFT  ...  37.799841
# 2015-05-13 21:00:00  LARCENY/THEFT  ...  37.787388
# 2015-05-13 21:00:00  LARCENY/THEFT  ...  37.732556
# 2015-05-13 21:00:00  LARCENY/THEFT  ...  37.744919
#
# [20 rows x 8 columns]

# %%
df = pd.read_csv('crimes.csv')
df['Dates'] = pd.to_datetime(df.Dates)
df.set_index('Dates', inplace=True)
df.head(10)

# %%
df.plot.scatter(x='X', y='Y')

# %%
df
# Out:
#            #  carat        cut color  ...     y     z  expensive  volume_label
# 0          1   0.23      Ideal     E  ...  3.98  2.43      False           big
# 1          2   0.21    Premium     E  ...  3.84  2.31      False           big
# 2          3   0.23       Good     E  ...  4.07  2.31      False           big
# 3          4   0.29    Premium     I  ...  4.23  2.63      False           big
# 4          5   0.31       Good     J  ...  4.35  2.75      False           big
# 5          6   0.24  Very Good     J  ...  3.96  2.48      False           big
# 6          7   0.24  Very Good     I  ...  3.98  2.47      False           big
# 7          8   0.26  Very Good     H  ...  4.11  2.53      False           big
# 8          9   0.22       Fair     E  ...  3.78  2.49      False           big
# 9         10   0.23  Very Good     H  ...  4.05  2.39      False           big
# 10        11   0.30       Good     J  ...  4.28  2.73      False           big
# 11        12   0.23      Ideal     J  ...  3.90  2.46      False           big
# 12        13   0.22    Premium     F  ...  3.84  2.33      False           big
# 13        14   0.31      Ideal     J  ...  4.37  2.71      False           big
# 14        15   0.20    Premium     E  ...  3.75  2.27      False           big
# 15        16   0.32    Premium     E  ...  4.42  2.68      False           big
# 16        17   0.30      Ideal     I  ...  4.34  2.68      False           big
# 17        18   0.30       Good     J  ...  4.29  2.70      False           big
# 18        19   0.30       Good     J  ...  4.26  2.71      False           big
# 19        20   0.30  Very Good     J  ...  4.27  2.66      False           big
# 20        21   0.30       Good     I  ...  4.30  2.71      False           big
# 21        22   0.23  Very Good     E  ...  3.92  2.48      False           big
# 22        23   0.23  Very Good     H  ...  3.96  2.41      False           big
# 23        24   0.31  Very Good     J  ...  4.43  2.62      False           big
# 24        25   0.31  Very Good     J  ...  4.47  2.59      False           big
# 25        26   0.23  Very Good     G  ...  4.01  2.41      False           big
# 26        27   0.24    Premium     I  ...  3.94  2.47      False           big
# 27        28   0.30  Very Good     J  ...  4.30  2.67      False           big
# 28        29   0.23  Very Good     D  ...  3.97  2.40      False           big
# 29        30   0.23  Very Good     F  ...  3.99  2.42      False           big
# ...      ...    ...        ...   ...  ...   ...   ...        ...           ...
# 53910  53911   0.70    Premium     E  ...  5.77  3.48       True           big
# 53911  53912   0.57    Premium     E  ...  5.38  3.23       True           big
# 53912  53913   0.61    Premium     F  ...  5.40  3.36       True           big
# 53913  53914   0.80       Good     G  ...  5.81  3.74       True           big
# 53914  53915   0.84       Good     I  ...  5.90  3.77       True           big
# 53915  53916   0.77      Ideal     E  ...  5.86  3.63       True           big
# 53916  53917   0.74       Good     D  ...  5.74  3.61       True           big
# 53917  53918   0.90  Very Good     J  ...  6.09  3.86       True           big
# 53918  53919   0.76    Premium     I  ...  5.85  3.49       True           big
# 53919  53920   0.76      Ideal     I  ...  5.87  3.66       True           big
# 53920  53921   0.70  Very Good     E  ...  5.61  3.49       True           big
# 53921  53922   0.70  Very Good     E  ...  5.65  3.53       True           big
# 53922  53923   0.70  Very Good     D  ...  5.58  3.55       True           big
# 53923  53924   0.73      Ideal     I  ...  5.84  3.57       True           big
# 53924  53925   0.73      Ideal     I  ...  5.84  3.59       True           big
# 53925  53926   0.79      Ideal     I  ...  5.97  3.67       True           big
# 53926  53927   0.71      Ideal     E  ...  5.73  3.54       True           big
# 53927  53928   0.79       Good     F  ...  6.13  3.54       True           big
# 53928  53929   0.79    Premium     E  ...  5.96  3.68       True           big
# 53929  53930   0.71      Ideal     G  ...  5.73  3.53       True           big
# 53930  53931   0.71    Premium     E  ...  5.74  3.49       True           big
# 53931  53932   0.71    Premium     F  ...  5.73  3.43       True           big
# 53932  53933   0.70  Very Good     E  ...  5.76  3.47       True           big
# 53933  53934   0.70  Very Good     E  ...  5.72  3.49       True           big
# 53934  53935   0.72    Premium     D  ...  5.73  3.58       True           big
# 53935  53936   0.72      Ideal     D  ...  5.76  3.50       True           big
# 53936  53937   0.72       Good     D  ...  5.75  3.61       True           big
# 53937  53938   0.70  Very Good     D  ...  5.68  3.56       True           big
# 53938  53939   0.86    Premium     H  ...  6.12  3.74       True           big
# 53939  53940   0.75      Ideal     D  ...  5.87  3.64       True           big
#
# [53940 rows x 13 columns]

# %%
df.head().to_json()
# Out:
# '{"#":{"0":1,"1":2,"2":3,"3":4,"4":5},"carat":{"0":0.23,"1":0.21,"2":0.23,"3":0.29,"4":0.31},"cut":{"0":"Ideal","1":"Premium","2":"Good","3":"Premium","4":"Good"},"color":{"0":"E","1":"E","2":"E","3":"I","4":"J"},"clarity":{"0":"SI2","1":"SI1","2":"VS1","3":"VS2","4":"SI2"},"depth":{"0":61.5,"1":59.8,"2":56.9,"3":62.4,"4":63.3},"table":{"0":55.0,"1":61.0,"2":65.0,"3":58.0,"4":58.0},"price":{"0":326,"1":326,"2":327,"3":334,"4":335},"x":{"0":3.95,"1":3.89,"2":4.05,"3":4.2,"4":4.34},"y":{"0":3.98,"1":3.84,"2":4.07,"3":4.23,"4":4.35},"z":{"0":2.43,"1":2.31,"2":2.31,"3":2.63,"4":2.75},"expensive":{"0":false,"1":false,"2":false,"3":false,"4":false},"volume_label":{"0":"big","1":"big","2":"big","3":"big","4":"big"}}'
